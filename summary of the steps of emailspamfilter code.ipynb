# %% [markdown]
# Email spam filtering  code using SVM and Naive bayes classifier to obtain confusion matrix and compare them i.e. to
# classify the emails as spam and ham using the concepts of Machine learning.Spam filtering is a binary classification task.
# The task is to distinguish between two types of emails, “spam” and “non-spam”.The dataset is obtained from uci repository.
# spam filter only filters out emails that have been previously marked as spam by customers.
#
# The first step is to import all the necessary libraries.
# A Counter is a container that keeps track of how many times equivalent values are added.It is used to calculate frequency of spam and ham(non spam) mails.
# Scikit-learn (sklearn)is a free software machine learning library for the Python programming language.[3] It features various classification, regression and clustering algorithms including support vector machines, random forests,  k-means .
#  then next step is to explore the dataset converted to pandas for easy manipulations.
#
#      explanation for few parameters:
# encoding : string, optional
# A string representing the encoding to use in the output file, defaults to ‘ascii’ on Python 2 and ‘utf-8’ on Python 3.
#
# sep : character, default ‘,’
# Field delimiter for the output file.
#
#
# quoting : optional constant from csv module
#
# defaults to csv.QUOTE_MINIMAL. If you have set a float_format then floats are converted to strings and thus
# csv.QUOTE_NONNUMERIC will treat them as non-numeric.
#
# use of rstrip: Strings in python (and other languages) are immutable, meaning once created they cannot be modified,
# so essentially line.rstrip() creates a new string instance with the stripped content.
#
# count is used to sort the dataframe by the count column max to min if it's not sorted that way already.
# extract the values from this in the order to plot the graph
# y axis shows the frequency of emails.
# x axis shows whether it is spam or ham.
#
# sklearn.feature_extraction.text.CountVectorizer is used for  Text preprocessing, tokenizing and filtering of stopwords
# ( A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine has been programmed
#  to ignore.)
# It Converts a collection of text documents to a matrix of token counts.
# A built-in stop word list for English is used.
#
# fit_transform may be more convenient and efficient for modelling and transforming the training data simultaneously.
# .shape is a tuple that gives dimensions of the array.
# numpy.arange is used to generating values within the half-open interval.
#
# We can split it into a training set that will be used to train the classifier, and
# a test set that will be used to evaluate it.
#
#
# I have used two algorithms:
#     Multinomial naive bayes'
#     Support vector machine(SVM)
#
#
#     The multinomial Naive Bayes classifier is suitable for classification with discrete features.
# the data divided into training set (most of data) and testing set (smaller portion) after the model processed by
# using the training set, you test the model by making prediction against the test set based on the value that
# determined for training set.
# We evaluate the accuracy, recall and precision of the model with the test set.
#    Between these models with the highest possible precision, we are going to selct which has more test accuracy.
#
#     confusion matrix is used to evaluate the quality of the output of a classifier on the  data set.
# The diagonal elements represent the number of points for which the predicted label is equal to the true label,
# while off-diagonal elements are those that are mislabeled by the classifier. The higher the diagonal values of the
# confusion matrix the better, indicating many correct predictions.
#
#
#
# OBSERVATIONS AND CONCLUSION:
#     The accuracy obtained is very high as it is predefined cleaned data.This may be so accurately applicable to any raw
#     datasets.Using Naive Bayes we misclassify 56 spam messages as non-spam emails whereas we don't misclassify any non-spam message.
#     Using SVM we misclassify 31 spam as non-spam messages whereas we don't misclassify any non-spam message.
#     Hence it is concluded that the best model  is support vector machine with 98.3% accuracy.It classifies every non-spam message correctly (Model precision)
